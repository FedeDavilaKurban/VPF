# %% [markdown]
# # RVPF - Integrated density contrast

# %%
import numpy as np
from cicTools import *
import matplotlib.pyplot as plt
import seaborn as sns

fs = 18
ms = 10

plt.rcParams["xtick.labelsize"] = fs
plt.rcParams["ytick.labelsize"] = fs
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams["font.family"] = "serif"
plt.rcParams["ytick.direction"] = 'in'
plt.rcParams["xtick.direction"] = 'in'

def chi_NB(x):
    return np.log(1+x)/x
def chi_T(x):
    return (np.sqrt(1+2*x)-1)/x

fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharex=False)
ax=axs[0]
ax1=axs[1]

xmin, xmax = 1E-1, 1E2 
x = np.geomspace(xmin,xmax,50)
#ax.plot(x,np.log(1+x)/x,label='NB',c='k',alpha=0.6)
#ax.plot(x,(np.sqrt(1+2*x)-1)/x,label='Therm.',c='k',ls='-.',alpha=0.6)
ax1.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax1.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)
ax.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)

# a=.2
# ax.plot(x,(1/((1-a)*(x/a)))*((1+x/a)**(1-a)-1),label='GH',c='k',ls='--',alpha=0.6)
# Q=1.2
# ax.plot(x,1-(np.euler_gamma+np.log(4*Q*x))/(8*Q),label='BBGKY',c='k',ls=':',alpha=0.6)

#-------------------------------------------------------------------------------------------
# Plotteo la curva fuera de voids para referenciar

# file = '../data/allgxs_nesf100000_jk_minMass1e11.npz'
# stats = np.load(file)

# chi = stats['arr_0']
# chi_std = stats['arr_1']
# NXi = stats['arr_2']
# NXi_std = stats['arr_3']
# P0 = stats['arr_4']
# P0_std = stats['arr_5']
# N_mean = stats['arr_6']
# N_mean_std = stats['arr_7']
# xi_mean = stats['arr_8']
# xi_mean_std = stats['arr_9']
# rs = stats['arr_10']

# P0err=delta_P0(P0,1E5)
# NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
# chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

# # chi vs Nxi
# #ax.errorbar(NXi,chi,xerr=NXierr,yerr=chierr,color='k',label='Box. M>1e11',ls=':')
# ax.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,color='k',label='Box. M>1e11',ls=':')

#---------------------------------------------------------------------------------------------

"""
REAL SPACE
"""
files = ['../data/allgxs_nesf20000_invoid_jk_v1e11_minradV9.0.npz',\
         '../data/allgxs_nesf20000_invoid_jk_v1e11_minradV9.0_d08.npz',\
         '../data/allgxs_nesf20000_invoid_jk_v1e11_minradV9.0_d07.npz']
markers = ['o','s','^']
labels = [r'$\Delta(R_v)$ = -0.9', r'$\Delta(R_v)$ = -0.8', r'$\Delta(R_v)$ = -0.7']
ypos_rmss = [.25,.15,.05]
colors = sns.dark_palette(sns.color_palette("tab10")[0], 4, reverse=True)[:3]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):

    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    P0err=delta_P0(P0,1E5)
    if '20000' in file: P0err=delta_P0(P0,20000)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([0,-1],[.12,.61],[.75,.65]):
            vline=ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-3,transform=ax.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,mfc='none',label=label,color=color,ms=ms)

    # RMS
    mask = np.isfinite(chi) #filter inf and NaN
    rms = np.sqrt(np.sum((chi[mask]-chi_NB(NXi[mask]))**2))
    ax.text(.7,ypos_rms,f'rms = {rms:.2E}',size=fs-1,color=ebar[0].get_color(),transform=ax.transAxes)


"""
REDSHIFT SPACE
"""
files = ['../data/allgxs_nesf20000_redshiftz_invoid_jk_v1e11_minradV9.0.npz',\
         '../data/allgxs_nesf20000_redshiftz_invoid_jk_v1e11_minradV9.0_d08.npz',\
         '../data/allgxs_nesf20000_redshiftz_invoid_jk_v1e11_minradV9.0_d07.npz']
markers = ['o','s','^']
labels = ['Delta = 0.9', 'Delta = 0.8','Delta = 0.7']
ypos_rmss = [.25,.15,.05] 
colors = sns.dark_palette(sns.color_palette("tab10")[3], 4, reverse=True)[:3]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):
    #print(file)
    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    # Errors
    P0err=delta_P0(P0,1E5)
    if '20000' in file: P0err=delta_P0(P0,20000)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([0,-1],[.12,.64],[.6,.6]):
            vline=ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax1.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax1.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,mfc='none',label=label,color=color,ms=ms)

    # RMS
    mask = np.isfinite(chi) #filter inf and NaN
    rms = np.sqrt(np.sum((chi[mask]-chi_NB(NXi[mask]))**2))
    ax1.text(.02,ypos_rms,f'rms = {rms:.2E}',size=fs-1,color=ebar[0].get_color(),transform=ax1.transAxes)
    

ax1.set_xscale('log')
ax.set_xscale('log')

ax.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)
#ax1.set_ylabel(r'$\Delta\chi_{NB}$',fontsize=fs)

ax.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)
ax1.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)
ylim1,ylim2 = -.06,.06
ax1.set_ylim([ylim1,ylim2])
ax.set_ylim([ylim1,ylim2])

ax.legend(loc=3,fontsize=fs,ncol=1,frameon=True,framealpha=.4,edgecolor='k')

#ax.set_xticklabels([])
ax1.set_yticklabels([])

ax.tick_params(labelsize=fs)
ax1.tick_params(labelsize=fs)
#ax.text(.025,.9,'Voids',fontsize=15,transform=ax.transAxes)
ax.text(.63,.9,'Real Space - Voids',fontsize=fs,transform=ax.transAxes)
ax1.text(.55,.9,'Redshift Space - Voids',fontsize=fs,transform=ax1.transAxes)

xlim1,xlim2=1E-1,5E1
ax.set_xlim(xlim1,xlim2)
ax1.set_xlim(xlim1,xlim2)

#ax.tick_params(labelsize=fs)
#ax.text(4,1,'Real Space Inside Voids',fontsize=15)

#plt.suptitle(r'RVPF dependency on integrated density contrast ($\Delta$) - Voids',fontsize=fs)
plt.tight_layout()
#plt.subplots_adjust(hspace=0,wspace=0.03)
plt.subplots_adjust(wspace=0.01)

plt.savefig('../plots/rVPF_intDelta.pdf')
#plt.savefig('../plots/rVPF_intDelta.png')
plt.show()

# %% [markdown]
# # VPF - galaxy mass

# %%
import numpy as np
from cicTools import *
import matplotlib.pyplot as plt
import seaborn as sns

fs = 18
ms = 10

plt.rcParams["xtick.labelsize"] = fs
plt.rcParams["ytick.labelsize"] = fs
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams["font.family"] = "serif"
plt.rcParams["ytick.direction"] = 'in'
plt.rcParams["xtick.direction"] = 'in'

def chi_NB(x):
    return np.log(1+x)/x
def chi_T(x):
    return (np.sqrt(1+2*x)-1)/x

fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharex=False)
ax=axs[0]
ax1=axs[1]

xmin, xmax = 1E-2, 1E2 
x = np.geomspace(xmin,xmax,50)
#ax.plot(x,np.log(1+x)/x,label='NB',c='k',alpha=0.6)
#ax.plot(x,(np.sqrt(1+2*x)-1)/x,label='Therm.',c='k',ls='-.',alpha=0.6)
ax1.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax1.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)
ax.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)

# a=.2
# ax.plot(x,(1/((1-a)*(x/a)))*((1+x/a)**(1-a)-1),label='GH',c='k',ls='--',alpha=0.6)
# Q=1.2
# ax.plot(x,1-(np.euler_gamma+np.log(4*Q*x))/(8*Q),label='BBGKY',c='k',ls=':',alpha=0.6)


#---------------------------------------------------------------------------------------------

"""
REAL SPACE
"""
nesf=20000
files = [f'../data/allgxs_nesf{nesf}_invoid_jk_maxMass1e10_v1e11_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_invoid_jk_minMass1e10_maxMass1e11_v1e11_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_invoid_jk_minMass1e11_v1e11_minradV9.0.npz']#,\
         #'../data/allgxs_nesf100000_invoid_jk_minMass1e12_v1e11_minradV9.0.npz']
markers = ['o','s','^']#,'o']
labels = [r'$1e9<M/M_\odot<1e10$', r'$1e10<M/M_\odot<1e11$',r'$M/M_\odot > 1e11$']#,'Mass > 1e12']
ypos_rmss = np.flip(np.linspace(.05,.05+.05*len(files),len(files)))
colors = sns.dark_palette(sns.color_palette("tab10")[0], 4, reverse=True)[:3]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):

    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    P0err=delta_P0(P0,nesf)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([0,6,-1],[.12,.515,.8],[.2,.32,.4]):
            vline=ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,mfc='none',label=label,color=color,ms=ms)
    print(chierr)

    # RMS
    mask = np.where(NXi>1E-1)
    #chirms = chi[mask]
    #mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chi[mask]-chi_NB(NXi[mask]))**2))
    ax.text(.7,ypos_rms,f'rms = {rms:.2E}',size=fs-2,color=ebar[0].get_color(),transform=ax.transAxes)


"""
REDSHIFT SPACE
"""
files = [f'../data/allgxs_nesf{nesf}_redshiftz_invoid_jk_maxMass1e10_v1e11_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_redshiftz_invoid_jk_minMass1e10_maxMass1e11_v1e11_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_redshiftz_invoid_jk_minMass1e11_v1e11_minradV9.0.npz']#,\
         #'../data/allgxs_nesf100000_redshiftz_invoid_jk_minMass1e12_v1e11_minradV9.0.npz']
markers = ['o','s','^']#,'o']
#labels = ['Mass > 1E09', 'Mass > 1E10','Mass > 1E11']#,'Mass > 1e12']
ypos_rmss = np.flip(np.linspace(.05,.05+.05*len(files),len(files)))
colors = sns.dark_palette(sns.color_palette("tab10")[3], 4, reverse=True)[:3]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):

    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    # Errors
    P0err=delta_P0(P0,nesf)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([0,6,-1],[.1,.52,.81],[.2,.62,.62]):
            vline=ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax1.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax1.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,mfc='none',label=label,color=color,ms=ms)

    # RMS
    mask = np.where(NXi>1E-1)
    rms = np.sqrt(np.sum((chi[mask]-chi_NB(NXi[mask]))**2))
    ax1.text(.7,ypos_rms,f'rms = {rms:.2E}',size=fs-2,color=ebar[0].get_color(),transform=ax1.transAxes)
    

# Log Scale
ax1.set_xscale('log')
ax.set_xscale('log')

# Y Labels
ax.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)

# X Labels
ax.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)
ax1.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)

# Y axis limis
ylim1,ylim2 = -.04,.04
ax.set_ylim([ylim1,ylim2])
ax1.set_ylim([ylim1,ylim2])

# X axis limits
xlim1,xlim2=1E-1,5E1
ax.set_xlim(xlim1,xlim2)
ax1.set_xlim(xlim1,xlim2)

# Legend
ax.legend(loc=1,fontsize=fs,ncol=1,frameon=True,framealpha=.6,edgecolor='k')
# leg = ax.get_legend()
# leg.legendHandles[0].set_color('k')
# leg.legendHandles[1].set_color('k')
# leg.legendHandles[2].set_color('k')

# Ticks
ax1.set_yticklabels([])
ax.tick_params(labelsize=fs)
ax1.tick_params(labelsize=fs)

# Additional text
ax.text(.05,.9,'Real Space - Voids',fontsize=fs,transform=ax.transAxes)
ax1.text(.55,.9,'Redshift Space - Voids',fontsize=fs,transform=ax1.transAxes)

# Final
#plt.suptitle('RVPF dependency on galaxy mass - Voids',fontsize=fs)
plt.tight_layout()
#plt.subplots_adjust(hspace=0,wspace=0.03)
plt.subplots_adjust(wspace=0.01)

plt.savefig('../plots/rVPF_invoid_gxsMass.pdf')
#plt.savefig('../plots/rVPF_invoid_gxsMass.png')
plt.show()
# Out:
# [8.78282093e-03 5.66391338e-03 4.47892945e-03 5.67330997e-03
#  2.82338364e-03 2.99975299e-03 1.80767118e-03 6.84152139e-04
#  3.18267169e-05 7.31728067e-06]
# [1.48912063e-03 6.74100346e-03 1.65582795e-03 4.39551466e-03
#  1.16413661e-03 4.72288634e-04 2.69582685e-03 2.61050311e-03
#  6.50235465e-04 7.45758360e-05]
# [       nan        nan 0.07097309 0.02098003 0.00561937 0.02209814
#  0.01378407 0.01476229 0.00652106 0.0085799 ]

# %%
import numpy as np
from cicTools import *
import matplotlib.pyplot as plt
import seaborn as sns

fs = 18
ms = 10

plt.rcParams["xtick.labelsize"] = fs
plt.rcParams["ytick.labelsize"] = fs
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams["font.family"] = "serif"
plt.rcParams["ytick.direction"] = 'in'
plt.rcParams["xtick.direction"] = 'in'

def chi_NB(x):
    return np.log(1+x)/x
def chi_T(x):
    return (np.sqrt(1+2*x)-1)/x

fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharex=False)
ax=axs[0]
ax1=axs[1]

xmin, xmax = 1E-3, 1E3 
x = np.geomspace(xmin,xmax,50)
#ax.plot(x,np.log(1+x)/x,label='NB',c='k',alpha=0.6)
#ax.plot(x,(np.sqrt(1+2*x)-1)/x,label='Therm.',c='k',ls='-.',alpha=0.6)
ax1.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax1.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)
ax.plot(x,chi_NB(x)-chi_T(x),c='k',alpha=0.6)
ax.plot(x,chi_T(x)-chi_T(x),c='k',ls='-.',alpha=0.6)

# a=.2
# ax.plot(x,(1/((1-a)*(x/a)))*((1+x/a)**(1-a)-1),label='GH',c='k',ls='--',alpha=0.6)
# Q=1.2
# ax.plot(x,1-(np.euler_gamma+np.log(4*Q*x))/(8*Q),label='BBGKY',c='k',ls=':',alpha=0.6)


#---------------------------------------------------------------------------------------------

"""
REAL SPACE
"""
files = ['../data/allgxs_nesf100000_jk_maxMass1e10.npz',\
         '../data/allgxs_nesf100000_jk_minMass1e10_maxMass1e11.npz',\
         '../data/allgxs_nesf100000_jk_minMass1e11.npz']#,\
         #'../data/allgxs_nesf100000_invoid_jk_minMass1e12_v1e11_minradV9.0.npz']
markers = ['o','s','^']#,'o']
labels = [r'$1e9<M/M_\odot<1e10$', r'$1e10<M/M_\odot<1e11$',r'$M/M_\odot > 1e11$']#,'Mass > 1e12']
ypos_rmss = [.8,.7,.6]
colors = sns.dark_palette(sns.color_palette("tab10")[0], 4, reverse=True)[:3]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):

    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    P0err=delta_P0(P0,1E5)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([2,6,-1],[.08,.39,.74],[.2,.2,.2]):
            vline=ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax.errorbar(NXi,chi-chi_T(NXi),xerr=NXierr,yerr=chierr,marker=marker,label=label,color=color,ms=ms)

    # RMS
    mask = np.where(NXi>1E-1)
    #chirms = chi[mask]
    #mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chi[mask]-chi_T(NXi[mask]))**2))
    ax.text(.7,ypos_rms,f'rms = {rms:.2E}',size=fs-2,color=ebar[0].get_color(),transform=ax.transAxes)


"""
REDSHIFT SPACE
"""
files = ['../data/allgxs_nesf100000_redshiftz_jk_maxMass1e10.npz',\
         '../data/allgxs_nesf100000_redshiftz_jk_minMass1e10_maxMass1e11.npz',\
         '../data/allgxs_nesf100000_redshiftz_jk_minMass1e11.npz']#,\
         #'../data/allgxs_nesf100000_redshiftz_invoid_jk_minMass1e12_v1e11_minradV9.0.npz']
markers = ['o','s','^']#,'o']
labels = ['Mass > 1E09', 'Mass > 1E10','Mass > 1E11']#,'Mass > 1e12']
ypos_rmss = [.8,.7,.6] 
colors = sns.dark_palette(sns.color_palette("tab10")[3], 4, reverse=True)[:3]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):
    #print(file)
    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    # Errors
    P0err=delta_P0(P0,1E5)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([2,6,-1],[.05,.3,.74],[.2,.2,.2]):
            vline=ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax1.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax1.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,label=label,color=color,ms=ms)

    # RMS
    #print(chi)
    mask = np.where(NXi>1E-1)
    #print(chi[mask])
    #chirms = chi[mask]
    #mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chi[mask]-chi_NB(NXi[mask]))**2))
    ax1.text(.05,ypos_rms,f'rms = {rms:.2E}',size=fs-2,color=ebar[0].get_color(),transform=ax1.transAxes)
    
# Log Scale
ax1.set_xscale('log')
ax.set_xscale('log')

# Y Labels
ax.set_ylabel(r'$\Delta\chi_{T}\equiv\chi-\chi_{T}$',fontsize=fs)
ax1.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)

# Set Y axis to right side
ax1.yaxis.set_label_position("right")
ax1.yaxis.tick_right()

# X Labels
ax.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)
ax1.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)

# Y axis limis
ylim1,ylim2 = -.12,.12
ax.set_ylim([ylim1,ylim2])
ax1.set_ylim([ylim1,ylim2])

# X axis limits
xlim1,xlim2=7E-2,9E2
ax.set_xlim(xlim1,xlim2)
ax1.set_xlim(xlim1,xlim2)

# Legend
ax.legend(loc=2,fontsize=fs-1,ncol=1,frameon=True,framealpha=.4,edgecolor='k')

# Ticks
#ax.set_xticklabels([])
#ax1.set_yticklabels([])
ax.tick_params(labelsize=fs)
ax1.tick_params(labelsize=fs)

# Additional text
ax.text(.75,.9,'Real Space',fontsize=fs,transform=ax.transAxes)
ax1.text(.68,.9,'Redshift Space',fontsize=fs,transform=ax1.transAxes)

# Final
#plt.suptitle('RVPF dependency on galaxy mass',fontsize=fs)
plt.tight_layout()
plt.subplots_adjust(hspace=0,wspace=0.01)
#plt.subplots_adjust(wspace=0.19)

plt.savefig('../plots/rVPF_gxsMass.pdf')
#plt.savefig('../plots/rVPF_gxsMass.png')
plt.show()

# %% [markdown]
# # VPF dependence on Redshift (w/ evolved integrated density contrast)

# %%
import numpy as np
from cicTools import *
import matplotlib.pyplot as plt
import seaborn as sns

fs = 18
ms = 10

plt.rcParams["xtick.labelsize"] = fs
plt.rcParams["ytick.labelsize"] = fs
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams["font.family"] = "serif"
plt.rcParams["ytick.direction"] = 'in'
plt.rcParams["xtick.direction"] = 'in'

def chi_NB(x):
    return np.log(1+x)/x
def chi_T(x):
    return (np.sqrt(1+2*x)-1)/x

fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharex=False)
ax=axs[0]
ax1=axs[1]

xmin, xmax = 1E-3, 1E3 
x = np.geomspace(xmin,xmax,50)
#ax.plot(x,np.log(1+x)/x,label='NB',c='k',alpha=0.6)
#ax.plot(x,(np.sqrt(1+2*x)-1)/x,label='Therm.',c='k',ls='-.',alpha=0.6)
ax1.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax1.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)
ax.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)

# a=.2
# ax.plot(x,(1/((1-a)*(x/a)))*((1+x/a)**(1-a)-1),label='GH',c='k',ls='--',alpha=0.6)
# Q=1.2
# ax.plot(x,1-(np.euler_gamma+np.log(4*Q*x))/(8*Q),label='BBGKY',c='k',ls=':',alpha=0.6)


#---------------------------------------------------------------------------------------------

"""
REAL SPACE
"""
nesf=20000
files = [f'../data/allgxs_nesf{nesf}_invoid_jk_v1e11_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_invoid_jk_snap67_v1e11EvolDelta_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_invoid_jk_snap50_v1e11EvolDelta_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_invoid_jk_snap33_v1e11EvolDelta_minradV9.0.npz']
markers = ['o','s','^','x']
labels = ['z=0', 'z=0.5','z=1', 'z=2']
ypos_rmss = [.35,.25,.15,.05]
colors = sns.dark_palette(sns.color_palette("tab10")[0], 5, reverse=True)[:4]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):

    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    P0err=delta_P0(P0,nesf)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([2,6,-1],[.3,.59,.8],[.1,.1,.1]):
            vline=ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,mfc='none',label=label,color=color,ms=ms)

    # RMS
    mask = np.where(NXi>1E-1)
    #chirms = chi[mask]
    #mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chi[mask]-chi_NB(NXi[mask]))**2))
    ax.text(.025,ypos_rms,f'rms = {rms:.2E}',size=fs-2,color=ebar[0].get_color(),transform=ax.transAxes)


"""
REDSHIFT SPACE
"""
files = [f'../data/allgxs_nesf{nesf}_redshiftz_invoid_jk_v1e11_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_redshiftz_invoid_jk_snap67_v1e11EvolDelta_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_redshiftz_invoid_jk_snap50_v1e11EvolDelta_minradV9.0.npz',\
         f'../data/allgxs_nesf{nesf}_redshiftz_invoid_jk_snap33_v1e11EvolDelta_minradV9.0.npz']
markers = ['o','s','^','x']
labels = ['z=0', 'z=0.5','z=1', 'z=2']
ypos_rmss = [.93,.83,.73,.63] 
colors = sns.dark_palette(sns.color_palette("tab10")[3], 5, reverse=True)[:4]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):
    #print(file)
    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    # Errors
    P0err=delta_P0(P0,nesf)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([2,6,-1],[.28,.6,.81],[.1,.1,.1]):
            vline=ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax1.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax1.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,mfc='none',label=label,color=color,ms=ms)

    # RMS
    #print(chi)
    mask = np.where(NXi>1E-1)
    #print(chi[mask])
    #chirms = chi[mask]
    #mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chi[mask]-chi_NB(NXi[mask]))**2))
    ax1.text(.02,ypos_rms,f'rms = {rms:.2E}',size=fs-2,color=ebar[0].get_color(),transform=ax1.transAxes)
    
# Log Scale
ax1.set_xscale('log')
ax.set_xscale('log')

# Y Labels
ax.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)
#ax1.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)

# Set Y axis to right side
# ax1.yaxis.set_label_position("right")
# ax1.yaxis.tick_right()

# X Labels
ax.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)
ax1.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)

# Y axis limis
ylim1,ylim2 = -.05,.05
ax.set_ylim([ylim1,ylim2])
ax1.set_ylim([ylim1,ylim2])

# X axis limits
xlim1,xlim2=1E-1,5E1
ax.set_xlim(xlim1,xlim2)
ax1.set_xlim(xlim1,xlim2)

# Legend
ax.legend(loc=2,fontsize=fs,ncol=2,frameon=True,framealpha=.4,edgecolor='k')

# Ticks
#ax.set_xticklabels([])
ax1.set_yticklabels([])
ax.tick_params(labelsize=fs)
ax1.tick_params(labelsize=fs)

# Additional text
ax.text(.62,.9,'Real Space - Voids',fontsize=fs,transform=ax.transAxes)
ax1.text(.54,.9,'Redshift Space - Voids',fontsize=fs,transform=ax1.transAxes)

# Final
#plt.suptitle('RVPF dependency on redshift - Voids',fontsize=fs)
#plt.subplots_adjust(hspace=0,wspace=0.03)
plt.tight_layout()
plt.subplots_adjust(wspace=0.01)

plt.savefig('../plots/rVPF_invoid_redshift_evolDelta.pdf')
#plt.savefig('../plots/rVPF_invoid_redshift_evolDelta.png')
plt.show()

# %%
import numpy as np
from cicTools import *
import matplotlib.pyplot as plt
import seaborn as sns

fs = 18
ms = 10

plt.rcParams["xtick.labelsize"] = fs
plt.rcParams["ytick.labelsize"] = fs
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams["font.family"] = "serif"
plt.rcParams["ytick.direction"] = 'in'
plt.rcParams["xtick.direction"] = 'in'

def chi_NB(x):
    return np.log(1+x)/x
def chi_T(x):
    return (np.sqrt(1+2*x)-1)/x
def chi_GH(x,a):
    return ((1+x/a)**(1-a)-1)*a/((1-a)*x)

fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharex=False)
ax=axs[0]
ax1=axs[1]

xmin, xmax = 1E-3, 1E3 
x = np.geomspace(xmin,xmax,50)
#ax.plot(x,chi_GH(x,.55)-chi_NB(x),c='k',ls=':',alpha=0.6)
#ax1.plot(x,chi_GH(x,1.5)-chi_NB(x),c='k',ls=':',alpha=0.6)
ax1.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax1.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)
ax.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)

# a=.2
# ax.plot(x,(1/((1-a)*(x/a)))*((1+x/a)**(1-a)-1),label='GH',c='k',ls='--',alpha=0.6)
# Q=1.2
# ax.plot(x,1-(np.euler_gamma+np.log(4*Q*x))/(8*Q),label='BBGKY',c='k',ls=':',alpha=0.6)


#---------------------------------------------------------------------------------------------

# Hardcoded values of z for snaps (tng-project.org/data/docs/specifications/)
n_snap = [2,3,4,6,8,11,13,17,21,\
          25,28,33,40,50,59,67,72,78,84,91,99]
redshift = ['z=12','z=11','z=10','z=9','z=8','z=7','z=6','z=5','z=4',\
            'z=3','z=2.58','z=2','z=1.5','z=1','z=0.7','z=0.5','z=0.4','z=0.3','z=0.2','z=0.1','z=0']
dict_snap_to_z=dict(zip(n_snap,redshift))

"""
REAL SPACE
"""

snaps=[99,67,50,33] #Snaps I want to plot
files = ['../data/allgxs_nesf100000_jk.npz']
for snap in snaps:
    if snap==99: continue
    files.append(f'../data/allgxs_nesf100000_jk_snap{snap}.npz')
    # elif snap!=25:
    #     files.append(f'../data/allgxs_nesf100000_jk_snap{snap}.npz')
    # elif snap==25:
    #     files.append(f'../data/allgxs_nesf100000_jk_snap25_minMass1e8.npz')


markers = ['o','s','^','x','<','>','v','*','D','P','1','2','3'][:len(files)]
labels = [dict_snap_to_z[snap] for snap in snaps]
ypos_rmss = [.8,.7,.6,.5,.4,.3,.2,.1,0][:len(files)]
colors = sns.dark_palette(sns.color_palette("tab10")[0], len(files)+1, reverse=True)[:len(files)]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):

    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    P0err=delta_P0(P0,1E5)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([2,6,-1],[.08,.4,.75],[.025,.025,.025]):
            vline=ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,color=color,label=label,ms=ms)

    # RMS
    #print(chi)
    mask = np.where(NXi>1E-1)
    #print(chi[mask])
    chirms = chi[mask]
    NXirms = NXi[mask]
    mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chirms[mask]-chi_NB(NXirms[mask]))**2))
    ax.text(.73,ypos_rms,f'rms = {rms:.2E}',size=fs-3,color=ebar[0].get_color(),transform=ax.transAxes)


"""
REDSHIFT SPACE
"""

files = ['../data/allgxs_nesf100000_redshiftz_jk.npz']
for snap in snaps:
    if snap==99: continue
    files.append(f'../data/allgxs_nesf100000_redshiftz_jk_snap{snap}.npz')
    # elif snap!=25:
    #     files.append(f'../data/allgxs_nesf100000_redshiftz_jk_snap{snap}.npz')
    # elif snap==25:
    #     files.append(f'../data/allgxs_nesf100000_redshiftz_jk_snap25_minMass1e8.npz')
markers = ['o','s','^','x','<','>','v','*','D','P','1','2','3'][:len(files)]
labels = [dict_snap_to_z[snap] for snap in snaps]
ypos_rmss = [.8,.7,.6,.5,.4,.3,.2,.1,0][:len(files)]
colors = sns.dark_palette(sns.color_palette("tab10")[3], len(files)+1, reverse=True)[:len(files)]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):
    print(file)
    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    # Errors
    P0err=delta_P0(P0,1E5)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([2,6,-1],[.05,.3,.76],[.025,.025,.025]):
            vline=ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax1.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax1.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,color=color,label=label,ms=ms)

    # RMS
    #print(chi)
    mask = np.where(NXi>1E-1)
    #print(chi[mask])
    chirms = chi[mask]
    NXirms = NXi[mask]
    mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chirms[mask]-chi_NB(NXirms[mask]))**2))
    ax1.text(.73,ypos_rms,f'rms = {rms:.2E}',size=fs-3,color=ebar[0].get_color(),transform=ax1.transAxes)
    
# Log Scale
ax1.set_xscale('log')
ax.set_xscale('log')

# Y Labels
ax.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)
#ax1.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)

# Set Y axis to right side
# ax1.yaxis.set_label_position("right")
# ax1.yaxis.tick_right()

# X Labels
ax.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)
ax1.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)

# Y axis limis
ylim1,ylim2 = -.05,.15
ax.set_ylim([ylim1,ylim2])
ax1.set_ylim([ylim1,ylim2])

# X axis limits
xlim1,xlim2=7E-2,9E2
ax.set_xlim(xlim1,xlim2)
ax1.set_xlim(xlim1,xlim2)

# Legend
ax.legend(loc=2,fontsize=fs,ncol=1,frameon=True,edgecolor='k',framealpha=.4)

# Ticks
#ax.set_xticklabels([])
ax1.set_yticklabels([])
ax.tick_params(labelsize=fs)
ax1.tick_params(labelsize=fs)

# Additional text
ax.text(.76,.9,'Real Space',fontsize=fs,transform=ax.transAxes)
ax1.text(.7,.9,'Redshift Space',fontsize=fs,transform=ax1.transAxes)

# Final
#plt.suptitle('RVPF dependency on redshift',fontsize=fs)
plt.tight_layout()
#plt.subplots_adjust(hspace=0,wspace=0.03)
plt.subplots_adjust(wspace=0.01)

plt.savefig('../plots/rVPF_redshift.pdf')
#plt.savefig('../plots/rVPF_redshift.png')
plt.show()
# Out:
# /media/fdavilakurban/0a842929-67de-4adc-b64c-8bc6d17a08b0/fdavilakurban/Proyectos/VPF/codes/cicTools.py:571: RuntimeWarning: divide by zero encountered in log
#   return chi*abs(P0err/(P0*abs(np.log(P0)))-N_mean_std/N_mean)
# /media/fdavilakurban/0a842929-67de-4adc-b64c-8bc6d17a08b0/fdavilakurban/Proyectos/VPF/codes/cicTools.py:571: RuntimeWarning: invalid value encountered in multiply
#   return chi*abs(P0err/(P0*abs(np.log(P0)))-N_mean_std/N_mean)
# ../data/allgxs_nesf100000_redshiftz_jk.npz
# ../data/allgxs_nesf100000_redshiftz_jk_snap67.npz
# ../data/allgxs_nesf100000_redshiftz_jk_snap50.npz
# ../data/allgxs_nesf100000_redshiftz_jk_snap33.npz

# %% [markdown]
# # VPF dependence on voids tracer mass

# %%
import numpy as np
from cicTools import *
import matplotlib.pyplot as plt
import seaborn as sns

fs = 18
ms = 10

plt.rcParams["xtick.labelsize"] = fs
plt.rcParams["ytick.labelsize"] = fs
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams["font.family"] = "serif"
plt.rcParams["ytick.direction"] = 'in'
plt.rcParams["xtick.direction"] = 'in'

def chi_NB(x):
    return np.log(1+x)/x
def chi_T(x):
    return (np.sqrt(1+2*x)-1)/x

fig, axs = plt.subplots(1, 2, figsize=(15, 5), sharex=False)
ax=axs[0]
ax1=axs[1]

xmin, xmax = 1E-3, 1E3 
x = np.geomspace(xmin,xmax,50)
#ax.plot(x,np.log(1+x)/x,label='NB',c='k',alpha=0.6)
#ax.plot(x,(np.sqrt(1+2*x)-1)/x,label='Therm.',c='k',ls='-.',alpha=0.6)
ax1.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax1.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)
ax.plot(x,chi_NB(x)-chi_NB(x),c='k',alpha=0.6)
ax.plot(x,chi_T(x)-chi_NB(x),c='k',ls='-.',alpha=0.6)

# a=.2
# ax.plot(x,(1/((1-a)*(x/a)))*((1+x/a)**(1-a)-1),label='GH',c='k',ls='--',alpha=0.6)
# Q=1.2
# ax.plot(x,1-(np.euler_gamma+np.log(4*Q*x))/(8*Q),label='BBGKY',c='k',ls=':',alpha=0.6)


#---------------------------------------------------------------------------------------------

"""
REAL SPACE
"""
files = ['../data/allgxs_nesf20000_invoid_jk_v1e11_minradV9.0.npz',\
         '../data/allgxs_nesf20000_invoid_jk_v1e10_minradV7.0.npz',\
         '../data/allgxs_nesf20000_invoid_jk_v1e9_minradV6.0.npz']
markers = ['o','s','^']#,'x']
labels = [r'$M_t\geq1e11M_\odot$',r'$M_t\geq1e10M_\odot$',r'$M_t\geq1e9M_\odot$']
ypos_rmss = [.3,.2,.1]
colors = sns.dark_palette(sns.color_palette("tab10")[0], 5, reverse=True)[:4]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):

    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']

    P0err=delta_P0(P0,1E5)
    if '20000' in file: P0err=delta_P0(P0,20000)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([0,6,-1],[.15,.5,.76],[.025,.025,.65]):
            vline=ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-4,transform=ax.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,color=color,mfc='none',label=label,ms=ms)

    # RMS
    #print(chi)
    mask = np.where(NXi>1E-1)
    #print(chi[mask])
    chirms = chi[mask]
    NXirms = NXi[mask]
    mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chirms[mask]-chi_NB(NXirms[mask]))**2))
    ax.text(.7,ypos_rms,f'rms = {rms:.2E}',size=fs-2,color=ebar[0].get_color(),transform=ax.transAxes)


"""
REDSHIFT SPACE
"""
files = ['../data/allgxs_nesf20000_redshiftz_invoid_jk_v1e11_minradV9.0.npz',\
         '../data/allgxs_nesf20000_redshiftz_invoid_jk_v1e10_minradV7.0.npz',\
         '../data/allgxs_nesf20000_redshiftz_invoid_jk_v1e9_minradV6.0.npz']
markers = ['o','s','^']#,'x']
labels = [r'$M_t\geq1e11M_\odot$',r'$M_t\geq1e10M_\odot$',r'$M_t\geq1e9M_\odot$']
ypos_rmss = [.3,.2,.1,]
colors = sns.dark_palette(sns.color_palette("tab10")[3], 5, reverse=True)[:4]

for file,marker,color,label,ypos_rms in zip(files,markers,colors,labels,ypos_rmss):
    #print(file)
    stats = np.load(file)

    chi = stats['arr_0']
    chi_std = stats['arr_1']
    NXi = stats['arr_2']
    NXi_std = stats['arr_3']
    P0 = stats['arr_4']
    P0_std = stats['arr_5']
    N_mean = stats['arr_6']
    N_mean_std = stats['arr_7']
    xi_mean = stats['arr_8']
    xi_mean_std = stats['arr_9']
    rs = stats['arr_10']
    #print(rs)

    # Errors
    P0err=delta_P0(P0,1E5)
    if '20000' in file: P0err=delta_P0(P0,20000)
    NXierr=delta_NXi(NXi,N_mean,N_mean_std,xi_mean,xi_mean_std)
    chierr=delta_chi(chi,P0,P0err,N_mean,N_mean_std)

    # Plot vlines with scales
    if marker=='o':
        space = 1.3
        lw = 1
        ls = ':'
        for ind,xpos_vline,ypos_vline in zip([0,6,-1],[.15,.5,.75],[.025,.025,.65]):
            vline=ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.axvline(NXi[ind],lw=lw,ls=ls,color=color)
            ax1.text(xpos_vline,ypos_vline,f'{rs[ind]/1000.:.2f}Mpc/h',\
                    size=fs-3,transform=ax1.transAxes,color=vline.get_color())

    # chi vs Nxi
    ebar = ax1.errorbar(NXi,chi-chi_NB(NXi),xerr=NXierr,yerr=chierr,marker=marker,color=color,mfc='none',label=label,ms=ms)

    # RMS
    #print(chi)
    mask = np.where(NXi>1E-1)
    #print(chi[mask])
    chirms = chi[mask]
    NXirms = NXi[mask]
    mask = np.isfinite(chirms) #filter inf and NaN
    rms = np.sqrt(np.sum((chirms[mask]-chi_NB(NXirms[mask]))**2))
    ax1.text(.7,ypos_rms,f'rms = {rms:.2E}',size=fs-2,color=ebar[0].get_color(),transform=ax1.transAxes)



# Log Scale
ax1.set_xscale('log')
ax.set_xscale('log')

# Y Labels
ax.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)
#ax1.set_ylabel(r'$\Delta\chi_{NB}\equiv\chi-\chi_{NB}$',fontsize=fs)

# Set Y axis to right side
# ax1.yaxis.set_label_position("right")
# ax1.yaxis.tick_right()

# X Labels
ax.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)
ax1.set_xlabel(r'$\bar{N}\bar{\xi}$',fontsize=fs)

# Y axis limis
ylim1,ylim2 = -.05,.07
ax.set_ylim([ylim1,ylim2])
ax1.set_ylim([ylim1,ylim2])

# X axis limits
xlim1,xlim2=1E-1,2E1
ax.set_xlim(xlim1,xlim2)
ax1.set_xlim(xlim1,xlim2)

# Legend
ax.legend(loc=2,fontsize=fs,ncol=1,frameon=True,framealpha=.6,edgecolor='k')

# Ticks
#ax.set_xticklabels([])
ax1.set_yticklabels([])
ax.tick_params(labelsize=fs)
ax1.tick_params(labelsize=fs)

# Additional text
ax.text(.62,.9,'Real Space - Voids',fontsize=fs,transform=ax.transAxes)
ax1.text(.56,.9,'Redshift Space - Voids',fontsize=fs,transform=ax1.transAxes)

# Final
#plt.suptitle(r'RVPF dependency on voids tracer mass ($M_t$)',fontsize=fs)
plt.tight_layout()
#plt.subplots_adjust(hspace=0,wspace=0.03)
plt.subplots_adjust(wspace=0.01)

plt.savefig('../plots/rVPF_voidTracerMass.pdf')
#plt.savefig('../plots/rVPF_voidTracerMass.png')
plt.show()
